# %% [markdown]
# # Random Forests Regressor Spring Break Assignment

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics
from scipy import stats

from sklearn.externals import joblib

# %%
PATH = "./data/"

# %%
# !ls {PATH}
# Out:
# data.csv  tmp

# %% [markdown]
# ## The data

# %%
df_raw = pd.read_csv(f'{PATH}data.csv', low_memory=False)

# %%
df_raw.Release_Clause = np.log(df_raw.Release_Clause)

# %%
df_raw.columns.values
# Out:
# array(['Unnamed: 0', 'ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage',
#        'Special', 'Preferred_Foot', 'International_Reputation', 'Weak_Foot', 'Skill_Moves', 'Work_Rate',
#        'Body_Type', 'Real_Face', 'Position', 'Jersey_Number', 'Loaned_From', 'Height', 'Weight', 'LS', 'ST',
#        'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina',
#        'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking',
#        'GKPositioning', 'GKReflexes', 'Release_Clause'], dtype=object)

# %%
df_raw.columns.values.size
# Out:
# 84

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
display_all(df_raw.tail().T)
# Out:
#                                     18202               18203  \
# Unnamed: 0                          18202               18203
# ID                                 238813              243165
# Name                         J. Lundstram  N. Christoffersson
# Age                                    19                  19
# Nationality                       England              Sweden
# Overall                                47                  47
# Potential                              65                  63
# Club                      Crewe Alexandra      Trelleborgs FF
# Value                               60000               60000
# Wage                                 1000                1000
# Special                              1307                1098
# Preferred_Foot                      Right               Right
# International_Reputation                1                   1
# Weak_Foot                               2                   2
# Skill_Moves                             2                   2
# Work_Rate                  Medium/ Medium      Medium/ Medium
# Body_Type                            Lean              Normal
# Real_Face                              No                  No
# Position                               CM                  ST
# Jersey_Number                          22                  21
# Loaned_From                           NaN                 NaN
# Height                                5'9                 6'3
# Weight                                134                 170
# LS                                   42+2                45+2
# ST                                   42+2                45+2
# RS                                   42+2                45+2
# LW                                   44+2                39+2
# LF                                   44+2                42+2
# CF                                   44+2                42+2
# RF                                   44+2                42+2
# RW                                   44+2                39+2
# LAM                                  45+2                40+2
# CAM                                  45+2                40+2
# RAM                                  45+2                40+2
# LM                                   44+2                38+2
# LCM                                  45+2                35+2
# CM                                   45+2                35+2
# RCM                                  45+2                35+2
# RM                                   44+2                38+2
# LWB                                  44+2                30+2
# LDM                                  45+2                31+2
# CDM                                  45+2                31+2
# RDM                                  45+2                31+2
# RWB                                  44+2                30+2
# LB                                   45+2                29+2
# LCB                                  45+2                32+2
# CB                                   45+2                32+2
# RCB                                  45+2                32+2
# RB                                   45+2                29+2
# Crossing                               34                  23
# Finishing                              38                  52
# HeadingAccuracy                        40                  52
# ShortPassing                           49                  43
# Volleys                                25                  36
# Dribbling                              42                  39
# Curve                                  30                  32
# FKAccuracy                             34                  20
# LongPassing                            45                  25
# BallControl                            43                  40
# Acceleration                           54                  41
# SprintSpeed                            57                  39
# Agility                                60                  38
# Reactions                              49                  40
# Balance                                76                  52
# ShotPower                              43                  41
# Jumping                                55                  47
# Stamina                                40                  43
# Strength                               47                  67
# LongShots                              38                  42
# Aggression                             46                  47
# Interceptions                          46                  16
# Positioning                            39                  46
# Vision                                 52                  33
# Penalties                              43                  43
# Composure                              45                  42
# Marking                                40                  22
# StandingTackle                         48                  15
# SlidingTackle                          47                  19
# GKDiving                               10                  10
# GKHandling                             13                   9
# GKKicking                               7                   9
# GKPositioning                           8                   5
# GKReflexes                              9                  12
# Release_Clause                    11.8706             11.6351
#
#                                      18204            18205            18206
# Unnamed: 0                           18204            18205            18206
# ID                                  241638           246268           246269
# Name                             B. Worman   D. Walker-Rice        G. Nugent
# Age                                     16               17               16
# Nationality                        England          England          England
# Overall                                 47               47               46
# Potential                               67               66               66
# Club                      Cambridge United  Tranmere Rovers  Tranmere Rovers
# Value                                60000            60000            60000
# Wage                                  1000             1000             1000
# Special                               1189             1228             1321
# Preferred_Foot                       Right            Right            Right
# International_Reputation                 1                1                1
# Weak_Foot                                3                3                3
# Skill_Moves                              2                2                2
# Work_Rate                   Medium/ Medium   Medium/ Medium   Medium/ Medium
# Body_Type                           Normal             Lean             Lean
# Real_Face                               No               No               No
# Position                                ST               RW               CM
# Jersey_Number                           33               34               33
# Loaned_From                            NaN              NaN              NaN
# Height                                 5'8             5'10             5'10
# Weight                                 148              154              176
# LS                                    45+2             47+2             43+2
# ST                                    45+2             47+2             43+2
# RS                                    45+2             47+2             43+2
# LW                                    45+2             47+2             45+2
# LF                                    46+2             46+2             44+2
# CF                                    46+2             46+2             44+2
# RF                                    46+2             46+2             44+2
# RW                                    45+2             47+2             45+2
# LAM                                   44+2             45+2             45+2
# CAM                                   44+2             45+2             45+2
# RAM                                   44+2             45+2             45+2
# LM                                    44+2             46+2             46+2
# LCM                                   38+2             39+2             45+2
# CM                                    38+2             39+2             45+2
# RCM                                   38+2             39+2             45+2
# RM                                    44+2             46+2             46+2
# LWB                                   34+2             36+2             46+2
# LDM                                   30+2             32+2             46+2
# CDM                                   30+2             32+2             46+2
# RDM                                   30+2             32+2             46+2
# RWB                                   34+2             36+2             46+2
# LB                                    33+2             35+2             46+2
# LCB                                   28+2             31+2             47+2
# CB                                    28+2             31+2             47+2
# RCB                                   28+2             31+2             47+2
# RB                                    33+2             35+2             46+2
# Crossing                                25               44               41
# Finishing                               40               50               34
# HeadingAccuracy                         46               39               46
# ShortPassing                            38               42               48
# Volleys                                 38               40               30
# Dribbling                               45               51               43
# Curve                                   38               34               40
# FKAccuracy                              27               32               34
# LongPassing                             28               32               44
# BallControl                             44               52               51
# Acceleration                            70               61               57
# SprintSpeed                             69               60               55
# Agility                                 50               52               55
# Reactions                               47               21               51
# Balance                                 58               71               63
# ShotPower                               45               64               43
# Jumping                                 60               42               62
# Stamina                                 55               40               47
# Strength                                32               48               60
# LongShots                               45               34               32
# Aggression                              32               33               56
# Interceptions                           15               22               42
# Positioning                             48               44               34
# Vision                                  43               47               49
# Penalties                               55               50               33
# Composure                               41               46               43
# Marking                                 32               20               40
# StandingTackle                          13               25               43
# SlidingTackle                           11               27               50
# GKDiving                                 6               14               10
# GKHandling                               5                6               15
# GKKicking                               10               14                9
# GKPositioning                            6                8               12
# GKReflexes                              13                9                9
# Release_Clause                     12.0137          11.8706          12.0137

# %%
display_all(df_raw.describe(include='all').T)
# Out:
#                           count unique              top   freq         mean  \
# Unnamed: 0                18207    NaN              NaN    NaN         9103
# ID                        18207    NaN              NaN    NaN       214298
# Name                      18207  17194     J. Rodríguez     11          NaN
# Age                       18207    NaN              NaN    NaN      25.1222
# Nationality               18207    164          England   1662          NaN
# Overall                   18207    NaN              NaN    NaN      66.2387
# Potential                 18207    NaN              NaN    NaN      71.3073
# Club                      17966    651  Manchester City     33          NaN
# Value                     18207    NaN              NaN    NaN  2.41778e+06
# Wage                      18207    NaN              NaN    NaN      9768.93
# Special                   18207    NaN              NaN    NaN      1597.81
# Preferred_Foot            18159      2            Right  13948          NaN
# International_Reputation  18159    NaN              NaN    NaN      1.11322
# Weak_Foot                 18159    NaN              NaN    NaN       2.9473
# Skill_Moves               18159    NaN              NaN    NaN      2.36131
# Work_Rate                 18159      9   Medium/ Medium   9810          NaN
# Body_Type                 18159     10           Normal  10595          NaN
# Real_Face                 18159      2               No  16505          NaN
# Position                  18147     27               ST   2152          NaN
# Jersey_Number             18147    NaN              NaN    NaN      19.5461
# Loaned_From                1264    341         Atalanta     20          NaN
# Height                    18159     21              6'0   2881          NaN
# Weight                    18159    NaN              NaN    NaN      165.979
# LS                        16122     93             61+2    705          NaN
# ST                        16122     93             61+2    705          NaN
# RS                        16122     93             61+2    705          NaN
# LW                        16122    105             63+2    745          NaN
# LF                        16122    102             61+2    713          NaN
# CF                        16122    102             61+2    713          NaN
# RF                        16122    102             61+2    713          NaN
# RW                        16122    105             63+2    745          NaN
# LAM                       16122    101             61+2    744          NaN
# CAM                       16122    101             61+2    744          NaN
# RAM                       16122    101             61+2    744          NaN
# LM                        16122    100             61+2    804          NaN
# LCM                       16122     92             58+2    762          NaN
# CM                        16122     92             58+2    762          NaN
# RCM                       16122     92             58+2    762          NaN
# RM                        16122    100             61+2    804          NaN
# LWB                       16122     95             61+2    713          NaN
# LDM                       16122     99             62+2    660          NaN
# CDM                       16122     99             62+2    660          NaN
# RDM                       16122     99             62+2    660          NaN
# RWB                       16122     95             61+2    713          NaN
# LB                        16122     98             61+2    669          NaN
# LCB                       16122    108             63+2    634          NaN
# CB                        16122    108             63+2    634          NaN
# RCB                       16122    108             63+2    634          NaN
# RB                        16122     98             61+2    669          NaN
# Crossing                  18159    NaN              NaN    NaN      49.7342
# Finishing                 18159    NaN              NaN    NaN      45.5509
# HeadingAccuracy           18159    NaN              NaN    NaN      52.2981
# ShortPassing              18159    NaN              NaN    NaN      58.6867
# Volleys                   18159    NaN              NaN    NaN       42.909
# Dribbling                 18159    NaN              NaN    NaN       55.371
# Curve                     18159    NaN              NaN    NaN      47.1708
# FKAccuracy                18159    NaN              NaN    NaN      42.8632
# LongPassing               18159    NaN              NaN    NaN      52.7119
# BallControl               18159    NaN              NaN    NaN      58.3695
# Acceleration              18159    NaN              NaN    NaN      64.6141
# SprintSpeed               18159    NaN              NaN    NaN       64.727
# Agility                   18159    NaN              NaN    NaN      63.5036
# Reactions                 18159    NaN              NaN    NaN      61.8366
# Balance                   18159    NaN              NaN    NaN      63.9666
# ShotPower                 18159    NaN              NaN    NaN        55.46
# Jumping                   18159    NaN              NaN    NaN      65.0894
# Stamina                   18159    NaN              NaN    NaN      63.2199
# Strength                  18159    NaN              NaN    NaN       65.312
# LongShots                 18159    NaN              NaN    NaN        47.11
# Aggression                18159    NaN              NaN    NaN       55.869
# Interceptions             18159    NaN              NaN    NaN      46.6983
# Positioning               18159    NaN              NaN    NaN      49.9585
# Vision                    18159    NaN              NaN    NaN      53.4009
# Penalties                 18159    NaN              NaN    NaN      48.5486
# Composure                 18159    NaN              NaN    NaN      58.6483
# Marking                   18159    NaN              NaN    NaN      47.2816
# StandingTackle            18159    NaN              NaN    NaN      47.6978
# SlidingTackle             18159    NaN              NaN    NaN      45.6614
# GKDiving                  18159    NaN              NaN    NaN      16.6162
# GKHandling                18159    NaN              NaN    NaN      16.3916
# GKKicking                 18159    NaN              NaN    NaN      16.2321
# GKPositioning             18159    NaN              NaN    NaN      16.3889
# GKReflexes                18159    NaN              NaN    NaN      16.7109
# Release_Clause            18207    NaN              NaN    NaN      14.1016
#
#                                   std     min      25%      50%      75%  \
# Unnamed: 0                    5256.05       0   4551.5     9103  13654.5
# ID                            29965.2      16   200316   221759   236530
# Name                              NaN     NaN      NaN      NaN      NaN
# Age                           4.66994      16       21       25       28
# Nationality                       NaN     NaN      NaN      NaN      NaN
# Overall                       6.90893      46       62       66       71
# Potential                      6.1365      48       67       71       75
# Club                              NaN     NaN      NaN      NaN      NaN
# Value                     5.59235e+06   10000   325000   675000    2e+06
# Wage                          21985.7    1000     1000     3000     9000
# Special                       272.586     731     1457     1635     1787
# Preferred_Foot                    NaN     NaN      NaN      NaN      NaN
# International_Reputation     0.394031       1        1        1        1
# Weak_Foot                    0.660456       1        3        3        3
# Skill_Moves                  0.756164       1        2        2        3
# Work_Rate                         NaN     NaN      NaN      NaN      NaN
# Body_Type                         NaN     NaN      NaN      NaN      NaN
# Real_Face                         NaN     NaN      NaN      NaN      NaN
# Position                          NaN     NaN      NaN      NaN      NaN
# Jersey_Number                 15.9478       1        8       17       26
# Loaned_From                       NaN     NaN      NaN      NaN      NaN
# Height                            NaN     NaN      NaN      NaN      NaN
# Weight                        15.5933     110      154      165      176
# LS                                NaN     NaN      NaN      NaN      NaN
# ST                                NaN     NaN      NaN      NaN      NaN
# RS                                NaN     NaN      NaN      NaN      NaN
# LW                                NaN     NaN      NaN      NaN      NaN
# LF                                NaN     NaN      NaN      NaN      NaN
# CF                                NaN     NaN      NaN      NaN      NaN
# RF                                NaN     NaN      NaN      NaN      NaN
# RW                                NaN     NaN      NaN      NaN      NaN
# LAM                               NaN     NaN      NaN      NaN      NaN
# CAM                               NaN     NaN      NaN      NaN      NaN
# RAM                               NaN     NaN      NaN      NaN      NaN
# LM                                NaN     NaN      NaN      NaN      NaN
# LCM                               NaN     NaN      NaN      NaN      NaN
# CM                                NaN     NaN      NaN      NaN      NaN
# RCM                               NaN     NaN      NaN      NaN      NaN
# RM                                NaN     NaN      NaN      NaN      NaN
# LWB                               NaN     NaN      NaN      NaN      NaN
# LDM                               NaN     NaN      NaN      NaN      NaN
# CDM                               NaN     NaN      NaN      NaN      NaN
# RDM                               NaN     NaN      NaN      NaN      NaN
# RWB                               NaN     NaN      NaN      NaN      NaN
# LB                                NaN     NaN      NaN      NaN      NaN
# LCB                               NaN     NaN      NaN      NaN      NaN
# CB                                NaN     NaN      NaN      NaN      NaN
# RCB                               NaN     NaN      NaN      NaN      NaN
# RB                                NaN     NaN      NaN      NaN      NaN
# Crossing                      18.3645       5       38       54       64
# Finishing                     19.5258       2       30       49       62
# HeadingAccuracy               17.3799       4       44       56       64
# ShortPassing                  14.6995       7       54       62       68
# Volleys                       17.6944       4       30       44       57
# Dribbling                     18.9104       4       49       61       68
# Curve                         18.3953       6       34       48       62
# FKAccuracy                    17.4788       3       31       41       57
# LongPassing                   15.3279       9       43       56       64
# BallControl                   16.6866       5       54       63       69
# Acceleration                  14.9278      12       57       67       75
# SprintSpeed                     14.65      12       57       67       75
# Agility                        14.766      14       55       66       74
# Reactions                     9.01046      21       56       62       68
# Balance                       14.1362      16       56       66       74
# ShotPower                      17.238       2       45       59       68
# Jumping                         11.82      15       58       66       73
# Stamina                       15.8947      12       56       66       74
# Strength                       12.557      17       58       67       74
# LongShots                     19.2605       3       33       51       62
# Aggression                     17.368      11       44       59       69
# Interceptions                 20.6969       3       26       52       64
# Positioning                    19.529       2       38       55       64
# Vision                        14.1469      10       44       55       64
# Penalties                     15.7041       5       39       49       60
# Composure                     11.4361       3       51       60       67
# Marking                       19.9044       3       30       53       64
# StandingTackle                 21.664       2       27       55       66
# SlidingTackle                 21.2891       3       24       52       64
# GKDiving                      17.6953       1        8       11       14
# GKHandling                    16.9069       1        8       11       14
# GKKicking                     16.5029       1        8       11       14
# GKPositioning                 17.0347       1        8       11       14
# GKReflexes                    17.9551       1        8       11       14
# Release_Clause                1.41058  9.4727  13.1382  13.9108  14.9141
#
#                                 max
# Unnamed: 0                    18206
# ID                           246620
# Name                            NaN
# Age                              45
# Nationality                     NaN
# Overall                          94
# Potential                        95
# Club                            NaN
# Value                     1.185e+08
# Wage                         565000
# Special                        2346
# Preferred_Foot                  NaN
# International_Reputation          5
# Weak_Foot                         5
# Skill_Moves                       5
# Work_Rate                       NaN
# Body_Type                       NaN
# Real_Face                       NaN
# Position                        NaN
# Jersey_Number                    99
# Loaned_From                     NaN
# Height                          NaN
# Weight                          243
# LS                              NaN
# ST                              NaN
# RS                              NaN
# LW                              NaN
# LF                              NaN
# CF                              NaN
# RF                              NaN
# RW                              NaN
# LAM                             NaN
# CAM                             NaN
# RAM                             NaN
# LM                              NaN
# LCM                             NaN
# CM                              NaN
# RCM                             NaN
# RM                              NaN
# LWB                             NaN
# LDM                             NaN
# CDM                             NaN
# RDM                             NaN
# RWB                             NaN
# LB                              NaN
# LCB                             NaN
# CB                              NaN
# RCB                             NaN
# RB                              NaN
# Crossing                         93
# Finishing                        95
# HeadingAccuracy                  94
# ShortPassing                     93
# Volleys                          90
# Dribbling                        97
# Curve                            94
# FKAccuracy                       94
# LongPassing                      93
# BallControl                      96
# Acceleration                     97
# SprintSpeed                      96
# Agility                          96
# Reactions                        96
# Balance                          96
# ShotPower                        95
# Jumping                          95
# Stamina                          96
# Strength                         97
# LongShots                        94
# Aggression                       95
# Interceptions                    92
# Positioning                      95
# Vision                           94
# Penalties                        92
# Composure                        96
# Marking                          94
# StandingTackle                   93
# SlidingTackle                    91
# GKDiving                         90
# GKHandling                       92
# GKKicking                        91
# GKPositioning                    90
# GKReflexes                       94
# Release_Clause              19.2453

# %% [markdown]
# ### Initial processing

# %% [markdown]
# The categorical variables are currently stored as strings, which is inefficient, and doesn't provide the numeric coding required for a random forest. Therefore we call `train_cats` to convert strings to pandas categories.

# %%
train_cats(df_raw)
#df_raw.describe()

# %% [markdown]
# We can specify the order to use for categorical variables if we wish:

# %%
df_raw.Name.cat.categories
# Out:
# Index(['A. Abang', 'A. Abdellaoui', 'A. Abdennour', 'A. Abdi', 'A. Abdu Jaber',
#        'A. Abdulhameed', 'A. Abedzadeh', 'A. Abeid', 'A. Ablet', 'A. Abrashi',
#        ...
#        'Éverton Luiz', 'Ícaro', 'Íñigo López', 'Óliver Torres', 'Óscar',
#        'Óscar Gil', 'Óscar Pinchi', 'Óscar Plano', 'Óscar Valentín',
#        'Óscar Whalley'],
#       dtype='object', length=17194)

# %%
#df_raw.UsageBand.cat.set_categories(['x', 'b', 'o'], ordered=True, inplace=True)

# %% [markdown]
# Normally, pandas will continue displaying the text categories, while treating them as numerical data internally. Optionally, we can replace the text categories with numbers, which will make this variable non-categorical, like so:.

# %%
#df_raw.a1 = df_raw.a1.cat.codes

# %% [markdown]
# Do we have missing values? We can't pass these directly to a random forest.

# %%
display_all(df_raw.isnull().sum().sort_index()/len(df_raw))
# Out:
# Acceleration                0.002636
# Age                         0.000000
# Aggression                  0.002636
# Agility                     0.002636
# Balance                     0.002636
# BallControl                 0.002636
# Body_Type                   0.002636
# CAM                         0.114516
# CB                          0.114516
# CDM                         0.114516
# CF                          0.114516
# CM                          0.114516
# Club                        0.013237
# Composure                   0.002636
# Crossing                    0.002636
# Curve                       0.002636
# Dribbling                   0.002636
# FKAccuracy                  0.002636
# Finishing                   0.002636
# GKDiving                    0.002636
# GKHandling                  0.002636
# GKKicking                   0.002636
# GKPositioning               0.002636
# GKReflexes                  0.002636
# HeadingAccuracy             0.002636
# Height                      0.002636
# ID                          0.000000
# Interceptions               0.002636
# International_Reputation    0.002636
# Jersey_Number               0.003295
# Jumping                     0.002636
# LAM                         0.114516
# LB                          0.114516
# LCB                         0.114516
# LCM                         0.114516
# LDM                         0.114516
# LF                          0.114516
# LM                          0.114516
# LS                          0.114516
# LW                          0.114516
# LWB                         0.114516
# Loaned_From                 0.930576
# LongPassing                 0.002636
# LongShots                   0.002636
# Marking                     0.002636
# Name                        0.000000
# Nationality                 0.000000
# Overall                     0.000000
# Penalties                   0.002636
# Position                    0.003295
# Positioning                 0.002636
# Potential                   0.000000
# Preferred_Foot              0.002636
# RAM                         0.114516
# RB                          0.114516
# RCB                         0.114516
# RCM                         0.114516
# RDM                         0.114516
# RF                          0.114516
# RM                          0.114516
# RS                          0.114516
# RW                          0.114516
# RWB                         0.114516
# Reactions                   0.002636
# Real_Face                   0.002636
# Release_Clause              0.000000
# ST                          0.114516
# ShortPassing                0.002636
# ShotPower                   0.002636
# Skill_Moves                 0.002636
# SlidingTackle               0.002636
# Special                     0.000000
# SprintSpeed                 0.002636
# Stamina                     0.002636
# StandingTackle              0.002636
# Strength                    0.002636
# Unnamed: 0                  0.000000
# Value                       0.000000
# Vision                      0.002636
# Volleys                     0.002636
# Wage                        0.000000
# Weak_Foot                   0.002636
# Weight                      0.002636
# Work_Rate                   0.002636
# dtype: float64

# %% [markdown]
# But let's save this file for now, since it's already in format can we be stored and accessed efficiently.

# %%
os.makedirs(f'{PATH}tmp', exist_ok=True)
df_raw.to_feather(f'{PATH}tmp/data-raw')

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# In the future we can simply read it from this fast format.

# %%
df_raw = pd.read_feather(f'{PATH}tmp/data-raw')

# %% [markdown]
# We'll replace categories with their numeric codes, handle missing continuous values, and split the dependent variable into a separate variable.

# %%
df, y, _ = proc_df(df_raw, 'Release_Clause')
df, y
# Out:
# (       Unnamed: 0      ID   Name  Age  Nationality  Overall  Potential  Club  \
#  0               0  158023   9633   31            7       94         94   213
#  1               1   20801   3154   33          124       94         94   327
#  2               2  190871  12509   26           21       92         93   436
#  3               3  193080   4137   27          140       91         93   376
#  4               4  192985   8618   27           14       91         92   375
#  5               5  183277   4420   27           14       91         91   135
#  6               6  177003   9641   32           36       91         91   471
#  7               7  176580   9842   31          159       91         91   213
#  8               8  155862  15418   32          140       91         91   471
#  9               9  200389   7776   25          137       90         93    62
#  10             10  188545  13856   29          123       90         90   215
#  11             11  182521  15795   28           60       90         90   471
#  12             12  182493   3477   32          159       90         90    62
#  13             13  168542   4130   32          140       90         90   375
#  14             14  215914  12233   27           56       89         90   135
#  15             15  211110  12963   24            7       89         94   327
#  16             16  202126   6233   24           47       89         91   584
#  17             17  194765    581   27           56       89         90    62
#  18             18  192448  11782   26           60       89         92   213
#  19             19  192119  15619   26           14       89         90   471
#  20             20  189511  15409   29          140       89         89   213
#  21             21  179813   4328   31          159       89         89   436
#  22             22  167495  11198   32           60       89         89   215
#  23             23  153079  14391   30            7       89         89   375
#  24             24  138956   5572   33           79       89         89   327
#  25             25  231747   8832   19           56       88         95   436
#  26             26  209331  11460   26           45       88         89   364
#  27             27  200145   3055   26           21       88         90   471
#  28             28  198710   7912   26           32       88         89   215
#  29             29  198219   9512   27           79       88         88   399
#  ...           ...     ...    ...  ...          ...      ...        ...   ...
#  18177       18177  238550  14023   18          127       48         69    81
#  18178       18178  243158   9897   18          145       48         65   178
#  18179       18179  246243   8181   17           47       48         64   408
#  18180       18180  221669  10833   22          132       48         58   557
#  18181       18181  245734   2678   17          127       48         66    93
#  18182       18182  246001  16791   18           32       48         65    64
#  18183       18183   53748   8931   44           47       48         48   123
#  18184       18184  241657   3528   18           47       48         55   363
#  18185       18185  243961   4660   19          127       48         59   189
#  18186       18186  240917  17108   20           31       47         64    74
#  18187       18187  240158   2463   19           60       47         59   548
#  18188       18188  240927   9343   17          162       47         62   407
#  18189       18189  240160    705   18           60       47         61   548
#  18190       18190  245569   9906   18           47       47         67   123
#  18191       18191  245570   7759   18           47       47         65   123
#  18192       18192  245571  15217   18           47       47         64   123
#  18193       18193  244823  12164   18           30       47         64   600
#  18194       18194  245862   7686   18           79       47         65   354
#  18195       18195  243582  14712   18          127       47         67   630
#  18196       18196  238477   8668   19           82       47         61   328
#  18197       18197  246167   3522   18          127       47         61   161
#  18198       18198  242844   7567   18           47       47         70   103
#  18199       18199  244677  10284   18           26       47         69   608
#  18200       18200  231381   8199   18          132       47         62   572
#  18201       18201  243413   3999   18          127       47         68   630
#  18202       18202  238813   7581   19           47       47         65   166
#  18203       18203  243165  12102   19          145       47         63   588
#  18204       18204  241638   2134   16           47       47         67   123
#  18205       18205  246268   3998   17           47       47         66   587
#  18206       18206  246269   5808   16           47       46         66   587
#
#                Value      Wage  ...  Penalties_na  Composure_na  Marking_na  \
#  0      1.105000e+08  565000.0  ...         False         False       False
#  1      7.700000e+07  405000.0  ...         False         False       False
#  2      1.185000e+08  290000.0  ...         False         False       False
#  3      7.200000e+07  260000.0  ...         False         False       False
#  4      1.020000e+08  355000.0  ...         False         False       False
#  5      9.300000e+07  340000.0  ...         False         False       False
#  6      6.700000e+07  420000.0  ...         False         False       False
#  7      8.000000e+07  455000.0  ...         False         False       False
#  8      5.100000e+07  380000.0  ...         False         False       False
#  9      6.800000e+07   94000.0  ...         False         False       False
#  10     7.700000e+07  205000.0  ...         False         False       False
#  11     7.650000e+07  355000.0  ...         False         False       False
#  12     4.400000e+07  125000.0  ...         False         False       False
#  13     6.000000e+07  285000.0  ...         False         False       False
#  14     6.300000e+07  225000.0  ...         False         False       False
#  15     8.900000e+07  205000.0  ...         False         False       False
#  16     8.350000e+07  205000.0  ...         False         False       False
#  17     7.800000e+07  145000.0  ...         False         False       False
#  18     5.800000e+07  240000.0  ...         False         False       False
#  19     5.350000e+07  240000.0  ...         False         False       False
#  20     5.150000e+07  315000.0  ...         False         False       False
#  21     6.000000e+07  200000.0  ...         False         False       False
#  22     3.800000e+07  130000.0  ...         False         False       False
#  23     6.450000e+07  300000.0  ...         False         False       False
#  24     2.700000e+07  215000.0  ...         False         False       False
#  25     8.100000e+07  100000.0  ...         False         False       False
#  26     6.950000e+07  255000.0  ...         False         False       False
#  27     5.950000e+07  285000.0  ...         False         False       False
#  28     6.950000e+07  315000.0  ...         False         False       False
#  29     6.200000e+07  165000.0  ...         False         False       False
#  ...             ...       ...  ...           ...           ...         ...
#  18177  7.000000e+04    1000.0  ...         False         False       False
#  18178  5.000000e+04    1000.0  ...         False         False       False
#  18179  5.000000e+04    1000.0  ...         False         False       False
#  18180  4.000000e+04    1000.0  ...         False         False       False
#  18181  5.000000e+04    1000.0  ...         False         False       False
#  18182  5.000000e+04    1000.0  ...         False         False       False
#  18183  5.416667e+04    1000.0  ...         False         False       False
#  18184  4.000000e+04    1000.0  ...         False         False       False
#  18185  5.000000e+04    1000.0  ...         False         False       False
#  18186  6.000000e+04    1000.0  ...         False         False       False
#  18187  4.000000e+04    1000.0  ...         False         False       False
#  18188  6.000000e+04    1000.0  ...         False         False       False
#  18189  6.000000e+04    1000.0  ...         False         False       False
#  18190  6.000000e+04    1000.0  ...         False         False       False
#  18191  5.000000e+04    1000.0  ...         False         False       False
#  18192  5.000000e+04    1000.0  ...         False         False       False
#  18193  5.000000e+04    1000.0  ...         False         False       False
#  18194  5.000000e+04    1000.0  ...         False         False       False
#  18195  6.000000e+04    1000.0  ...         False         False       False
#  18196  6.000000e+04    1000.0  ...         False         False       False
#  18197  6.000000e+04    1000.0  ...         False         False       False
#  18198  6.000000e+04    1000.0  ...         False         False       False
#  18199  7.000000e+04    1000.0  ...         False         False       False
#  18200  6.000000e+04    1000.0  ...         False         False       False
#  18201  6.000000e+04    1000.0  ...         False         False       False
#  18202  6.000000e+04    1000.0  ...         False         False       False
#  18203  6.000000e+04    1000.0  ...         False         False       False
#  18204  6.000000e+04    1000.0  ...         False         False       False
#  18205  6.000000e+04    1000.0  ...         False         False       False
#  18206  6.000000e+04    1000.0  ...         False         False       False
#
#         StandingTackle_na  SlidingTackle_na  GKDiving_na  GKHandling_na  \
#  0                  False             False        False          False
#  1                  False             False        False          False
#  2                  False             False        False          False
#  3                  False             False        False          False
#  4                  False             False        False          False
#  5                  False             False        False          False
#  6                  False             False        False          False
#  7                  False             False        False          False
#  8                  False             False        False          False
#  9                  False             False        False          False
#  10                 False             False        False          False
#  11                 False             False        False          False
#  12                 False             False        False          False
#  13                 False             False        False          False
#  14                 False             False        False          False
#  15                 False             False        False          False
#  16                 False             False        False          False
#  17                 False             False        False          False
#  18                 False             False        False          False
#  19                 False             False        False          False
#  20                 False             False        False          False
#  21                 False             False        False          False
#  22                 False             False        False          False
#  23                 False             False        False          False
#  24                 False             False        False          False
#  25                 False             False        False          False
#  26                 False             False        False          False
#  27                 False             False        False          False
#  28                 False             False        False          False
#  29                 False             False        False          False
#  ...                  ...               ...          ...            ...
#  18177              False             False        False          False
#  18178              False             False        False          False
#  18179              False             False        False          False
#  18180              False             False        False          False
#  18181              False             False        False          False
#  18182              False             False        False          False
#  18183              False             False        False          False
#  18184              False             False        False          False
#  18185              False             False        False          False
#  18186              False             False        False          False
#  18187              False             False        False          False
#  18188              False             False        False          False
#  18189              False             False        False          False
#  18190              False             False        False          False
#  18191              False             False        False          False
#  18192              False             False        False          False
#  18193              False             False        False          False
#  18194              False             False        False          False
#  18195              False             False        False          False
#  18196              False             False        False          False
#  18197              False             False        False          False
#  18198              False             False        False          False
#  18199              False             False        False          False
#  18200              False             False        False          False
#  18201              False             False        False          False
#  18202              False             False        False          False
#  18203              False             False        False          False
#  18204              False             False        False          False
#  18205              False             False        False          False
#  18206              False             False        False          False
#
#         GKKicking_na  GKPositioning_na  GKReflexes_na
#  0             False             False          False
#  1             False             False          False
#  2             False             False          False
#  3             False             False          False
#  4             False             False          False
#  5             False             False          False
#  6             False             False          False
#  7             False             False          False
#  8             False             False          False
#  9             False             False          False
#  10            False             False          False
#  11            False             False          False
#  12            False             False          False
#  13            False             False          False
#  14            False             False          False
#  15            False             False          False
#  16            False             False          False
#  17            False             False          False
#  18            False             False          False
#  19            False             False          False
#  20            False             False          False
#  21            False             False          False
#  22            False             False          False
#  23            False             False          False
#  24            False             False          False
#  25            False             False          False
#  26            False             False          False
#  27            False             False          False
#  28            False             False          False
#  29            False             False          False
#  ...             ...               ...            ...
#  18177         False             False          False
#  18178         False             False          False
#  18179         False             False          False
#  18180         False             False          False
#  18181         False             False          False
#  18182         False             False          False
#  18183         False             False          False
#  18184         False             False          False
#  18185         False             False          False
#  18186         False             False          False
#  18187         False             False          False
#  18188         False             False          False
#  18189         False             False          False
#  18190         False             False          False
#  18191         False             False          False
#  18192         False             False          False
#  18193         False             False          False
#  18194         False             False          False
#  18195         False             False          False
#  18196         False             False          False
#  18197         False             False          False
#  18198         False             False          False
#  18199         False             False          False
#  18200         False             False          False
#  18201         False             False          False
#  18202         False             False          False
#  18203         False             False          False
#  18204         False             False          False
#  18205         False             False          False
#  18206         False             False          False
#
#  [18207 rows x 122 columns],
#  array([19.23826, 18.66048, 19.24529, ..., 12.0137 , 11.8706 , 12.0137 ]))

# %%
def split_vals(a,n): 
    return a[:n].copy(), a[n:].copy()

n_valid = 6400
n_valid = len(df)-n_valid
raw_train, raw_valid = split_vals(df_raw, n_valid)

# %%
X_train, X_valid = split_vals(df, n_valid)
y_train, y_valid = split_vals(y, n_valid)
X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((11807, 122), (11807,), (6400, 122), (6400,))

# %% [markdown]
# # Random Forests

# %%
m = RandomForestRegressor(n_jobs=-1)
m.fit(df, y)
m.score(df,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9983624232927595

# %%
def rmse(x,y):
    return math.sqrt(((x-y)**2).mean())
def print_score(m):
    res = [rmse(m.predict(X_train), y_train),
        rmse(m.predict(X_valid), y_valid),
        m.score(X_train, y_train), m.score(X_valid, y_valid)]
    print(res)

# %%
m = RandomForestRegressor(n_jobs=-1)
# %time m.fit(X_train, y_train)
print_score(m)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# CPU times: user 3.97 s, sys: 0 ns, total: 3.97 s
# Wall time: 550 ms
# [0.05771801067399967, 0.2832246083518588, 0.9978445716440073, 0.8459376832231932]

# %%
plt.figure()
plt.scatter(X_train, y_train, s=20, edgecolor="black",
            c="darkorange", label="data")
#plt.plot(X_test, y_1, color="cornflowerblue",
#         label="max_depth=2", linewidth=2)
plt.plot(X_valid, y_valid, color="yellowgreen", label="max_depth=3", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-97e26eb35056> in <module>
#       1 plt.figure()
#       2 plt.scatter(X_train, y_train, s=20, edgecolor="black",
# ----> 3             c="darkorange", label="data")
#       4 #plt.plot(X_test, y_1, color="cornflowerblue",
#       5 #         label="max_depth=2", linewidth=2)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2860         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2861         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2862         is not None else {}), **kwargs)
#    2863     sci(__ret)
#    2864     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4180         y = np.ma.ravel(y)
#    4181         if x.size != y.size:
# -> 4182             raise ValueError("x and y must be the same size")
#    4183
#    4184         if s is None:
#
# ValueError: x and y must be the same size

# %%
joblib.dump(m, 'model.pkl')
# Out:
# ['model.pkl']
