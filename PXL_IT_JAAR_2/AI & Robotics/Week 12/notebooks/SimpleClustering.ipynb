# %%
from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.datasets import make_circles
from sklearn.datasets import make_moons

# %%
nb_samples = 1000
X, _ = make_blobs(n_samples=nb_samples, n_features=2, centers=3,
cluster_std=1.5)
plt.scatter(X[:, 0], X[:, 1], s=50);

# %%
km = KMeans(n_clusters=3)

# %%
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
y_kmeans = km.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = km.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
nb_samples = 1000
X, _ = make_moons(n_samples=nb_samples, noise=0.05)

# %%
plt.scatter(X[:, 0], X[:, 1], s=50);

# %%
km = KMeans(n_clusters=2)

# %%
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
y_kmeans = km.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = km.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
from sklearn.cluster import DBSCAN

# %%
dbs = DBSCAN(eps=0.1)

# %%
y_dbscan = dbs.fit_predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_dbscan, s=50, cmap='viridis')

centers = dbs.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-e56eef8c1726> in <module>
#       1 plt.scatter(X[:, 0], X[:, 1], c=y_dbscan, s=50, cmap='viridis')
#       2
# ----> 3 centers = dbs.cluster_centers_
#       4 plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
#
# AttributeError: 'DBSCAN' object has no attribute 'cluster_centers_'
